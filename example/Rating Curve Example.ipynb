# %%
import pandas as pd
from  RatingCurve import RatingCurve

# %%
# _load data_

sampleData = pd.read_csv('data/SampleDataRC.csv')
obs_wl = sampleData['Water Level'].values
obs_q = sampleData['Discharge'].values

# %%
ratingCurve = RatingCurve(obs_wl,obs_q,'segmented')
ratingCurve.fit()
# Out:
# Suggested Rating curves:-
#
# 1) MSE: 4866.96
# 	[H  < 19.54] 0.03*(H - 1.05)^4.92
# 	[H >= 19.54] 0.01*(H - 7.90)^6.36
#
# 2) MSE: 5147.20
# 	[H  < 16.28] 0.01*(H - 0.73)^5.13
# 	[H >= 16.28] 0.00*(H - 0.67)^6.13
#
# 3) MSE: 5228.16
# 	[H  < 13.02] 339.03*(H - 0.78)^1.03
# 	[H >= 13.02] 0.00*(H - 0.10)^5.68
#
# 4) MSE: 5238.31
# 	[H  < 11.97] 0.07*(H - 0.10)^0.00
# 	[H >= 11.97] 0.00*(H - 0.13)^5.60
#
# 5) MSE: 5476.16
# 	[H  < 11.97] 100.00*(H - 1.25)^1.76
# 	[H >= 11.97] 88.33*(H - 8.81)^2.69

# %%
ratingCurve.showPlot(1)
